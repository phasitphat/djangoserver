# %%
import os

# %%
pwd
# Out:
# u'C:\\Users\\AzEulB\\cs459\\real_db'

# %%
path=os.path.join('..','material','bert')
print path
all_img=os.listdir(path)
# Out:
# ..\material\bert

# %%
Product.objects.all()
# Out:
# []

# %%
all_img
# Out:
# ['Adidasring.png',
#  'Adidasring2.png',
#  'Adidas_case.png',
#  'Alice.png',
#  'Alien.png',
#  'Animals_whole.png',
#  'Appleman.png',
#  'Areal.png',
#  'Ass.png',
#  'Baconegg.png',
#  'Bang.png',
#  'Bath.png',
#  'Batman.png',
#  'Bear_gold.png',
#  'Beer.png',
#  'Blackring.png',
#  'Blueheart.png',
#  'Bluepaint.png',
#  'Bluering.png',
#  'Bringit.png',
#  'Burberry_logo.png',
#  'Burberry_plain.png',
#  'Captainring.png',
#  'Cats_pizza.png',
#  'Cats_purple.png',
#  'Cat_juk.png',
#  'Cat_juk2.png',
#  'Cat_rainbow.png',
#  'Chanel.png',
#  'Christmas.png',
#  'Cinnamonroll_1.png',
#  'City_blue.png',
#  'Cloud_thunder.png',
#  'Cupcake_juk.png',
#  'Cupcake_rainbow.png',
#  'Daisy_1.png',
#  'Daisy_2.png',
#  'Daisy_ring.png',
#  'Dear.png',
#  'Diamondgold.png',
#  'Diamonsilver.png',
#  'Dogs.png',
#  'Donalduck_1.png',
#  'Donut_pink.png',
#  'Donut_white8bit.png',
#  'Doraemonring1.png',
#  'Doraemonring2.png',
#  'Doraemonring3.png',
#  'Doraemonring4.png',
# ...

# %%
from django.core.files import File
for i in all_img:
    pic=os.path.join(path,i)
    print pic
    f=File(open(pic,'rb'))
    img=Product(Product_Name=f.name)
    img=Product(Product_Price=350.00)
    img=Product(Product_Quantity=10)
    img=Product(Product_Detail="Product Available")
    img.Product_Image.save(f.name, f)
# Out:
# ..\material\bert\Adidasring.png
# ..\material\bert\Adidasring2.png
# ..\material\bert\Adidas_case.png
# ..\material\bert\Alice.png
# ..\material\bert\Alien.png
# ..\material\bert\Animals_whole.png
# ..\material\bert\Appleman.png
# ..\material\bert\Areal.png
# ..\material\bert\Ass.png
# ..\material\bert\Baconegg.png
# ..\material\bert\Bang.png
# ..\material\bert\Bath.png
# ..\material\bert\Batman.png
# ..\material\bert\Bear_gold.png
# ..\material\bert\Beer.png
# ..\material\bert\Blackring.png
# ..\material\bert\Blueheart.png
# ..\material\bert\Bluepaint.png
# ..\material\bert\Bluering.png
# ..\material\bert\Bringit.png
# ..\material\bert\Burberry_logo.png
# ..\material\bert\Burberry_plain.png
# ..\material\bert\Captainring.png
# ..\material\bert\Cats_pizza.png
# ..\material\bert\Cats_purple.png
# ..\material\bert\Cat_juk.png
# ..\material\bert\Cat_juk2.png
# ..\material\bert\Cat_rainbow.png
# ..\material\bert\Chanel.png
# ..\material\bert\Christmas.png
# ...

# %%
from django.core.files import File
for i in all_img:
    pic=os.path.join(path,i)
    print pic
    f=File(open(pic,'rb'))
    print img.Product_Image.save(f.name, f)
# Out:
# ..\material\bert\Adidasring.png
# None
# ..\material\bert\Adidasring2.png
# None
# ..\material\bert\Adidas_case.png
# None
# ..\material\bert\Alice.png
# None
# ..\material\bert\Alien.png
# None
# ..\material\bert\Animals_whole.png
# None
# ..\material\bert\Appleman.png
# None
# ..\material\bert\Areal.png
# None
# ..\material\bert\Ass.png
# None
# ..\material\bert\Baconegg.png
# None
# ..\material\bert\Bang.png
# None
# ..\material\bert\Bath.png
# None
# ..\material\bert\Batman.png
# None
# ..\material\bert\Bear_gold.png
# None
# ..\material\bert\Beer.png
# None
# ..\material\bert\Blackring.png
# None
# ..\material\bert\Blueheart.png
# None
# ..\material\bert\Bluepaint.png
# None
# ..\material\bert\Bluering.png
# None
# ..\material\bert\Bringit.png
# None
# ..\material\bert\Burberry_logo.png
# None
# ..\material\bert\Burberry_plain.png
# None
# ..\material\bert\Captainring.png
# None
# ..\material\bert\Cats_pizza.png
# None
# ..\material\bert\Cats_purple.png
# None
# ...

# %%
print f.name
# Out:
# ..\material\bert\Wavy_blue.png

# %%
from django.contrib.sessions.models import Session
from django.contrib.sessions.backends.db import SessionStore

# %%
Session.objects.all()

# %%
print all_img[0]
